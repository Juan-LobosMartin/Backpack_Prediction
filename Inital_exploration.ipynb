# %%
# Modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Backpack_df = pd.read_csv('Data/train.csv')
Backpack_df.head(3)
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0         No       Tote  Black             11.611723  112.15875
# 1        Yes  Messenger  Green             27.078537   68.88056
# 2         No  Messenger    Red             16.643760   39.17320

# %%
Backpack_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    300000 non-null  int64
#  1   Brand                 290295 non-null  object
#  2   Material              291653 non-null  object
#  3   Size                  293405 non-null  object
#  4   Compartments          300000 non-null  float64
#  5   Laptop Compartment    292556 non-null  object
#  6   Waterproof            292950 non-null  object
#  7   Style                 292030 non-null  object
#  8   Color                 290050 non-null  object
#  9   Weight Capacity (kg)  299862 non-null  float64
#  10  Price                 300000 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 25.2+ MB

# %%
Backpack_df.describe()
# Out:
#                   id   Compartments  Weight Capacity (kg)          Price
# count  300000.000000  300000.000000         299862.000000  300000.000000
# mean   149999.500000       5.443590             18.029994      81.411107
# std     86602.684716       2.890766              6.966914      39.039340
# min         0.000000       1.000000              5.000000      15.000000
# 25%     74999.750000       3.000000             12.097867      47.384620
# 50%    149999.500000       5.000000             18.068614      80.956120
# 75%    224999.250000       8.000000             24.002375     115.018160
# max    299999.000000      10.000000             30.000000     150.000000

# %%
Backpack_df['Brand'].value_counts(dropna= False)
# Out:
# Brand
# Adidas          60077
# Under Armour    59992
# Nike            57336
# Puma            56814
# Jansport        56076
# NaN              9705
# Name: count, dtype: int64

# %%
Backpack_df.columns
# Out:
# Index(['id', 'Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)', 'Price'],
#       dtype='object')

# %%
# to see all values in columns
for column in Backpack_df.columns:
    print(f"Value Counts for Column '{column}':")
    print(Backpack_df[column].value_counts(dropna=False))
    print("-" * 30)  # Separator for clarity
# Out:
# Value Counts for Column 'id':
# id
# 0         1
# 199988    1
# 200004    1
# 200003    1
# 200002    1
#          ..
# 99999     1
# 99998     1
# 99997     1
# 99996     1
# 299999    1
# Name: count, Length: 300000, dtype: int64
# ------------------------------
# Value Counts for Column 'Brand':
# Brand
# Adidas          60077
# Under Armour    59992
# Nike            57336
# Puma            56814
# Jansport        56076
# NaN              9705
# Name: count, dtype: int64
# ------------------------------
# Value Counts for Column 'Material':
# Material
# Polyester    79630
# Leather      73416
# Nylon        70603
# Canvas       68004
# NaN           8347
# Name: count, dtype: int64
# ------------------------------
# Value Counts for Column 'Size':
# Size
# Medium    101906
# Large      98643
# Small      92856
# NaN         6595
# Name: count, dtype: int64
# ------------------------------
# Value Counts for Column 'Compartments':
# Compartments
# 1.0     31568
# 4.0     31498
# ...

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Style', y='Weight Capacity (kg)', data=Backpack_df)
plt.title('Weight max Vs Style')
plt.xlabel('Style')
plt.ylabel('Weight Capacity (kg)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Size', y='Price', data=Backpack_df, color='green')
plt.title('Price Vs Size')
plt.xlabel('Size')
plt.ylabel('Price')
plt.savefig('Fig/Violin_Price_sice.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Size', y='Weight Capacity (kg)', data=Backpack_df)
plt.title('Weight max Vs Size')
plt.xlabel('Size')
plt.ylabel('Weight Capacity (kg)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Compartments', y='Price', data=Backpack_df) # jitter adds a bit of random noise to x-axis
plt.title('Price vs. Number of Compartments')
plt.xlabel('Number of Compartments')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Compartments', y='Price', data=Backpack_df)  # Shows mean and confidence intervals
plt.title('Average Price by Number of Compartments')
plt.xlabel('Number of Compartments')
plt.ylabel('Average Price')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x='Compartments', y='Price', data=Backpack_df, marker='o') # Add markers to show data points
plt.title('Price Trend by Number of Compartments')
plt.xlabel('Number of Compartments')
plt.ylabel('Price')
plt.xticks(range(1, 11)) # Make sure all x-axis values are shown.
plt.show()

# %%
Backpack_df['Waterproof'].value_counts()
# number of items without descriptions of Waterproof 7050
# Out:
# Waterproof
# Yes    148077
# No     144873
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Compartments', y='Weight Capacity (kg)', data=Backpack_df, color='green') # jitter adds a bit of random noise to x-axis
plt.title('Price vs. Number of Compartments')
plt.xlabel('Number of Compartments')
plt.ylabel('Weight Capacity (kg)')
plt.show()

# %%
sns.pairplot(Backpack_df, hue="Material", diag_kind="hist")
